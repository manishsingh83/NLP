# %% [markdown]
# # Speech-To-Text

# %%
import pydub

# %%
import speech_recognition as sr

# %%
# initialize the recognizer
r = sr.Recognizer()

# %% [markdown]
# **First**

# %%
file = 'E:\Download\Aristotle_Life_changing.wav'
with sr.AudioFile(file) as source:  # Opening the file
    audio_data = r.record(source)   # listen for the data (load audio to memory)
    text_1 = r.recognize_google(audio_data)    # recognizer (convert from speech to text)
    print(text_1)
# Out:
# result2:
# {   'alternative': [   {   'confidence': 0.90616524,
#                            'transcript': 'carriage is the first of human '
#                                          'qualities because it is the quality '
#                                          'which guarantees the others in order '
#                                          'that we may have pleasure just as we '
#                                          'get to go in order that we may have '
#                                          "please learning is not child's play "
#                                          'we cannot learn without pain '
#                                          'suffering becomes beautiful when '
#                                          "anyone there's great calamities with "
#                                          'cheerfulness not through '
#                                          'insensibility but true greatness of '
# ...

# %%
f_1 = open('Aristotle_Life_changing.txt', 'w')
f_1.write(text_1)
f_1.close()

# %% [markdown]
# **MAKING A FUNCTION FOR CONVERTING SPEECH TO TEXT**

# %%
import speech_recognition as sr
import os
from pydub import AudioSegment
from pydub.silence import split_on_silence

# create a speech recognition object
r = sr.Recognizer()

# a function that splits the audio file into chunks
#   and applies speech recognition
def get_large_audio_transcription(path):
    """
    Splitting the large audio file into chunks
    and apply speech recognition on each of these chunks """
    # open the audio file using pydub
    sound = AudioSegment.from_wav(path)
    # split audio sound where silence is 700 miliseconds or more and get chunks
    chunks = split_on_silence(sound,
        # experiment with this value for your target audio file
        min_silence_len = 500,
        silence_thresh = sound.dBFS-14, # adjust per requirment 
        keep_silence = 500,  # keep the silence for 1 second, adjustable as well
         )
    folder_name = 'audio_chunks'
    # create a directory to store the audio chunks
    if not os.path.isdir(folder_name):
        os.mkdir(folder_name)
    whole_text = ""
    # process each chunk
    for i, audio_chunk in enumerate(chunks, start=1):
        # export audio chunk and save it in
        # the 'folder_name' directory.
        chunk_filename = os.path.join(folder_name, f"chunk{1}.wav")
        audio_chunk.export(chunk_filename, format='wav')
        # recognize the chunk
        with sr.AudioFile(chunk_filename) as source:
            audio_listened = r.record(source)
            # try converting it to text
            try:
                text = r.recognize_google(audio_listened)
            except sr.UnknownValueError as e:
                print('error', str(e))
            else:
                text = f"{text.capitalize()}."
                print(chunk_filename, ":", text)
                whole_text += text
    # return the text for all chunks detected
    return whole_text

# %%
#path = "ml_speech_recognition.wav"
path = 'videoplayback.wav'
print("\n full text:", get_large_audio_transcription(path))
# Out:
# result2:
# []
# error
# result2:
# {   'alternative': [   {   'confidence': 0.9279117,
#                            'transcript': 'strong mind Vikas ideas average '
#                                          'minds discuss events weak minds '
#                                          'discuss people'},
#                        {   'transcript': 'strong mind Vikas Idea average minds '
#                                          'discuss events weak minds discuss '
#                                          'people'},
#                        {   'transcript': 'strong mind Vikas ideal average '
#                                          'minds discuss events weak minds '
#                                          'discuss people'},
#                        {   'transcript': 'John mind Vikas Idea average minds '
#                                          'discuss events weak minds discuss '
#                                          'people'},
# ...

# %% [markdown]
# # Text-To-Speech

# %%
# !pip install gTTS

# %%
# Import the required module for text to speech conversion
from gtts import gTTS

# This module is imported so that we can play the converted audio
import os

# %%
text = "The tesseract package is designed to compute concentrations of simulated dark matter halos from volume info \
        for particles generated using Voronoi tesselation"
# The language in which you want to convert
lang = 'en'

# Passing the text and language to the engine for converting the text to audio
audio = gTTS(text= text, lang= lang, slow=False) 

# Saving the converted audio in a mp3 file named, welcome
audio.save('ml.mp3')
print('finished')
# Out:
# finished
